# %% [markdown]
# # Pandas數據分析
#
# 今天介紹資料分析近來很紅的 pandas 套件, 作者是 Wes McKinney。Python 會成為一個數據分析的熱門語言, 和 pandas 的出現也有相當的關係。
#
# 但是 pandas 雖然功能強, 但有些地方沒那麼直覺, 有時會讓大家以為是個深奧的套件。其實你大約可以把 pandas 想成「Python 的 Excel」, 但是功能更強、更有彈性、也有更多的可能性。
#
# 下面介紹個基本上就是把 pandas 當 Excel 學的影片, 相信大家會覺得很親切。<br>
# https://youtu.be/9d5-Ti6onew

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1 開始使用 `pandas`
#
# 首先我們來讀入一個 CSV 檔, 這裡有個「假的」學測成績, 叫 `grades.csv` 我們來練習一下。

# %%
df = pd.read_csv("data/grades.csv")

# %% [markdown]
# 用 `df` 是標準的叫法 (雖然這名稱我們隨便取也可以), 意思是 Data Frame, 這是 `pandas` 兩大資料結構之一。我們可以把 Data Frame 想成一張表格 (雖然其實可以是很多張表格)。
#
# 我們來看看我們 `df` 的前五筆資料。

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %% [markdown]
# 如果你曾經手動讀入 CSV 檔, 就知道這省了多少事 (雖然我個人還挺喜歡純手動帶進 CSV)。

# %% [markdown]
# #### Excel 檔也可以快速讀入
#
# 不只 CSV 檔, 很多資料檔案, 像 Excel 檔都很容易在 `pandas` 完成。使用法是這樣:
#
#     df2 = pd.read_excel('filename.xls', 'sheetname')
#
# 其中 sheetname 那裡要放工作表的名稱, 如果是中文的最好改成英文。

# %% [markdown]
# ## 2 Pandas 基本資料結構
#
# Pandas 有兩個基本資料結構:
#
# * <b style="color:red;">DataFrame</b>: 可以想成一個表格。
# * <b style="color:red;">Series</b>: 表格的某一列、某一行, 基本上就是我們以前的 list 或 array
#
# 一個 DataFrame, 我們有 `index` (列的名稱), `columns` (行的名稱)。
#
# #### DataFrame
#
# ![DataFrame 的結構](images/indexcol.png)

# %% [markdown]
# #### Series
#
# 剛剛說 series 大概就是一個 list, 一個 array。其實更精準的說, 其實是一個有 "index" 的 array。
#
# DataFrame 的每一行或每一列其實也都是一個 series。我們來看個例子, 例如所有同學的國文成績, 就是一個 series。

# %%
df['國文']
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# 在 Python 3 中, 我們終於可以和英文同步, 用這種很炫的方式叫出所有國文成績。

# %%
df.國文
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# #### 資料畫出來
#
# 要畫個圖很容易。

# %%
df.國文.plot()

# %% [markdown]
# 當然, 在這個例子中, 其實畫 histogram 圖更有意義一點。

# %%
df.國文.hist(bins=15)

# %% [markdown]
# ## 3 一些基本的資料分析

# %% [markdown]
# 算平均。

# %%
df.國文.mean()
# Out:
# 11.39

# %% [markdown]
# 算標準差。

# %%
df.國文.std()
# Out:
# 2.1968526614594834

# %% [markdown]
# 不如就該算的都幫我們算算...

# %%
df.describe()
# Out:
#                國文          英文          數學         自然         社會
# count  100.000000  100.000000  100.000000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000
# std      2.196853    2.273164    2.310516    2.21772    2.48655
# min      8.000000    8.000000    8.000000    8.00000    8.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000

# %% [markdown]
# 有時我們很愛看的相關係數矩陣。

# %%
df.corr()
# Out:
#           國文        英文        數學        自然        社會
# 國文  1.000000  0.160158 -0.310899 -0.110236 -0.028421
# 英文  0.160158  1.000000  0.025656  0.113929 -0.063512
# 數學 -0.310899  0.025656  1.000000  0.014371  0.041651
# 自然 -0.110236  0.113929  0.014371  1.000000 -0.156594
# 社會 -0.028421 -0.063512  0.041651 -0.156594  1.000000

# %% [markdown]
# 只算兩科間的相關係數當然也可以。

# %%
df.國文.corr(df.數學)
# Out:
# -0.3108989822179331

# %% [markdown]
# ## 4 增加一行

# %% [markdown]
# ### 【技巧】
#
# 我們增加一行, 加入總級分。

# %%
df['Overall'] = df.sum(axis = 1)
df
# Out:
#      姓名  國文  英文  數學  自然  社會  Overall
# 0   劉俊安   9  10  15  10  13       57
# 1   胡玉華  10  10  10   8   9       47
# 2   黃淑婷  13  15   8  11  14       61
# 3   陳上紫  10  10   8   9  14       51
# 4   崔靜成  13  12  14  12  13       64
# ..  ...  ..  ..  ..  ..  ..      ...
# 95  蔡佳燕   9  10   9  13  14       55
# 96  吳筱婷   8  10  14  10  15       57
# 97  陳家銘  14   9  11   8  12       54
# 98  李明威  15   9   8   9  15       56
# 99  農揚勇   9  11  12  12  10       54
#
# [100 rows x 7 columns]

# %% [markdown]
# ### 【技巧】
#
# 有計算的當然也可以的。

# %%
df['加權'] =df.國文 + df.英文 + df.數學*2

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  Overall  加權
# 0  劉俊安   9  10  15  10  13       57  49
# 1  胡玉華  10  10  10   8   9       47  40
# 2  黃淑婷  13  15   8  11  14       61  44
# 3  陳上紫  10  10   8   9  14       51  36
# 4  崔靜成  13  12  14  12  13       64  53

# %% [markdown]
# ## 5 排序和 index 重設

# %% [markdown]
# ### 【重點】排序的方法
#
# 我們依總級分來排序。

# %%
df.sort_values(by='Overall', ascending=False).head(10)
# Out:
#      姓名  國文  英文  數學  自然  社會  Overall  加權
# 80  施雅鈴  13  15  12  13  13       66  52
# 12  李正偉  11  15  11  14  15       66  48
# 54  陳怡潔  15  15   9  15  11       65  48
# 25  蔡亦瑄  13  13  14  13  12       65  54
# 57  胡淳茜  12  15  14  13  11       65  55
# 37  曾怡君  11  12  15  13  14       65  53
# 48  陳怡婷  15  14  12   9  15       65  53
# 64  俞志峰   9  14  13  14  15       65  49
# 83  李士賢  10  14  15  13  13       65  54
# 87  趙偉希  10  13  14  13  15       65  51

# %% [markdown]
# ### 【重點】排序的方法
#
# 加權分最高, 同分才看總級分

# %%
df2 = df.sort_values(by=['加權','Overall'], ascending=False)

# %% [markdown]
# ### 【重點】重設 index

# %%
df2.index = range(1,101)
df2
# Out:
#       姓名  國文  英文  數學  自然  社會  Overall  加權
# 1    吳志遠  13  15  15   8   8       59  58
# 2    胡淳茜  12  15  14  13  11       65  55
# 3    詹威德  12  13  15  10  14       64  55
# 4    蔡亦瑄  13  13  14  13  12       65  54
# 5    李士賢  10  14  15  13  13       65  54
# ..   ...  ..  ..  ..  ..  ..      ...  ..
# 96   陳上紫  10  10   8   9  14       51  36
# 97   胡凱琳  10   8   9   9  15       51  36
# 98   林建亨   9  11   8   8  11       47  36
# 99   梁慧君   9   8   8   8  12       45  33
# 100  吳文伯   8   8   8  15  12       51  32
#
# [100 rows x 8 columns]

# %% [markdown]
# ## 6 篩出我們要的資料
#
# 基本上和 NumPy 的 array 篩法很像。

# %% [markdown]
# ### 【重點】
#
# 找出數學滿級分同學。

# %%
df2[df2.數學==15]
# Out:
#      姓名  國文  英文  數學  自然  社會  Overall  加權
# 1   吳志遠  13  15  15   8   8       59  58
# 3   詹威德  12  13  15  10  14       64  55
# 5   李士賢  10  14  15  13  13       65  54
# 7   曾怡君  11  12  15  13  14       65  53
# 10  林哲法  14   9  15  10  14       62  53
# 13  陳竹伯  10  12  15  10  14       61  52
# 15  葉儀依   9  13  15   8  14       59  52
# 18  周育霖   9  12  15  13  12       61  51
# 21  張雅彬  10  11  15  12   8       56  51
# 22  芮秋辛  11  10  15  10   8       54  51
# 25  胡勝傑   8  11  15  10  15       59  49
# 26  劉俊安   9  10  15  10  13       57  49
# 42  段冠廷   9   8  15  12  15       59  47

# %% [markdown]
# ### 【重點】
#
# 找出數學和英文都滿級分的同學。要注意 `and` 要用 `&`, `or` 要用 `|`。每個條件一定要加弧號。

# %%
df2[(df2.數學==15) & (df2.英文 ==15)]
# Out:
#     姓名  國文  英文  數學  自然  社會  Overall  加權
# 1  吳志遠  13  15  15   8   8       59  58

# %% [markdown]
# ## 7 刪除一行或一列

# %% [markdown]
# ### 【重點】刪掉一行
#
# 我們來刪掉總級分的那行。

# %%
df2 = df2.drop('國文',axis=1)
df2
# Out:
#       姓名  英文  數學  自然  社會  Overall  加權
# 1    吳志遠  15  15   8   8       59  58
# 2    胡淳茜  15  14  13  11       65  55
# 3    詹威德  13  15  10  14       64  55
# 4    蔡亦瑄  13  14  13  12       65  54
# 5    李士賢  14  15  13  13       65  54
# ..   ...  ..  ..  ..  ..      ...  ..
# 96   陳上紫  10   8   9  14       51  36
# 97   胡凱琳   8   9   9  15       51  36
# 98   林建亨  11   8   8  11       47  36
# 99   梁慧君   8   8   8  12       45  33
# 100  吳文伯   8   8  15  12       51  32
#
# [100 rows x 7 columns]

# %% [markdown]
# ### 【重點】改變原有的 DataFrame
#
# 我們會發現 `pandas` 很多動作都沒有更改原有的 DataFrame, 真的要改要加入
#
#     inplace=True

# %%
df2.drop('英文',axis=1, inplace=True)
df2
# Out:
#       姓名  數學  自然  社會  Overall  加權
# 1    吳志遠  15   8   8       59  58
# 2    胡淳茜  14  13  11       65  55
# 3    詹威德  15  10  14       64  55
# 4    蔡亦瑄  14  13  12       65  54
# 5    李士賢  15  13  13       65  54
# ..   ...  ..  ..  ..      ...  ..
# 96   陳上紫   8   9  14       51  36
# 97   胡凱琳   9   9  15       51  36
# 98   林建亨   8   8  11       47  36
# 99   梁慧君   8   8  12       45  33
# 100  吳文伯   8  15  12       51  32
#
# [100 rows x 6 columns]

# %% [markdown]
# ### 【重點】刪掉一列
#
# 刪掉列就是指定要刪去的 index。

# %%
df2.drop(5)
# Out:
#       姓名  數學  自然  社會  Overall  加權
# 1    吳志遠  15   8   8       59  58
# 2    胡淳茜  14  13  11       65  55
# 3    詹威德  15  10  14       64  55
# 4    蔡亦瑄  14  13  12       65  54
# 6    童心怡  14   8  13       61  54
# ..   ...  ..  ..  ..      ...  ..
# 96   陳上紫   8   9  14       51  36
# 97   胡凱琳   9   9  15       51  36
# 98   林建亨   8   8  11       47  36
# 99   梁慧君   8   8  12       45  33
# 100  吳文伯   8  15  12       51  32
#
# [99 rows x 6 columns]

# %% [markdown]
# ### 【重點】刪掉一列
#
# 通常刪掉符合條件的比較合理 (注意是找到要刪掉的部份, 再找出相對的 index)。

# %%
df2[df2.姓名 == '吳志遠']
df2
# Out:
#       姓名  數學  自然  社會  Overall  加權
# 1    吳志遠  15   8   8       59  58
# 2    胡淳茜  14  13  11       65  55
# 3    詹威德  15  10  14       64  55
# 4    蔡亦瑄  14  13  12       65  54
# 5    李士賢  15  13  13       65  54
# ..   ...  ..  ..  ..      ...  ..
# 96   陳上紫   8   9  14       51  36
# 97   胡凱琳   9   9  15       51  36
# 98   林建亨   8   8  11       47  36
# 99   梁慧君   8   8  12       45  33
# 100  吳文伯   8  15  12       51  32
#
# [100 rows x 6 columns]

# %%
df2.drop(df2[df2.姓名 == '吳志遠'].index)
# Out:
#       姓名  數學  自然  社會  Overall  加權
# 2    胡淳茜  14  13  11       65  55
# 3    詹威德  15  10  14       64  55
# 4    蔡亦瑄  14  13  12       65  54
# 5    李士賢  15  13  13       65  54
# 6    童心怡  14   8  13       61  54
# ..   ...  ..  ..  ..      ...  ..
# 96   陳上紫   8   9  14       51  36
# 97   胡凱琳   9   9  15       51  36
# 98   林建亨   8   8  11       47  36
# 99   梁慧君   8   8  12       45  33
# 100  吳文伯   8  15  12       51  32
#
# [99 rows x 6 columns]

# %% [markdown]
# ## 8 真實股價資料
#
# 有個從 `Pandas` 獨立出來的套件叫 `pandas-datareader`, 幾經波折, 先是 Yahoo! 的財務資料不能用, 後來又是 Google 的資料不能用, 不過至少現在看來 Yahoo! 還可以使用。
#
# 安裝 `pandas-datareader` 就標準 `conda` 安裝:
#
#     conda install pandas-datareader
#
# 如果裝過, 但很久沒更新就用:
#
#     conda update pandas-datareader

# %% [markdown]
# ### 【例子】 分析 Apple 股價

# %%
import pandas_datareader as pdr
df = pdr.get_data_yahoo('TSM')

# %%
# 為防止網路有問題, 我們把這個檔案以 aapl.csv 存起來, 可以這樣讀入。
# df = pd.read_csv('data/aapl.csv', index_col="Date")

# %%
df.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2020-06-15  56.119999  54.520000  54.709999  56.020000  7509700.0  54.669773
# 2020-06-16  57.000000  55.540001  56.590000  55.799999  8827200.0  54.455074
# 2020-06-17  56.820000  55.889999  56.150002  56.599998  8248700.0  55.235794
# 2020-06-18  56.540001  55.790001  56.040001  56.150002  6831500.0  55.206303
# 2020-06-19  56.500000  55.270000  56.480000  55.310001  6965100.0  54.380421

# %% [markdown]
# #### 只要最後 300 個交易日!

# %%
df = df[-3000:]
df
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-06-15   56.119999   54.520000   54.709999   56.020000   7509700.0
# 2020-06-16   57.000000   55.540001   56.590000   55.799999   8827200.0
# 2020-06-17   56.820000   55.889999   56.150002   56.599998   8248700.0
# 2020-06-18   56.540001   55.790001   56.040001   56.150002   6831500.0
# 2020-06-19   56.500000   55.270000   56.480000   55.310001   6965100.0
# ...                ...         ...         ...         ...         ...
# 2021-08-16  115.480003  114.099998  115.099998  114.629997   5435900.0
# 2021-08-17  113.849998  110.750000  113.730003  111.110001  13398800.0
# 2021-08-18  113.000000  110.379997  111.739998  110.449997   9167300.0
# 2021-08-19  110.970001  107.680000  109.000000  110.519997  12146900.0
# 2021-08-20  109.709999  107.730003  109.139999  108.120003  13021900.0
#
#              Adj Close
# Date
# 2020-06-15   54.669773
# 2020-06-16   54.455074
# 2020-06-17   55.235794
# ...

# %% [markdown]
# #### 20 日的移動平均

# %%
df.Close.plot()
df.Close.rolling(20).mean().plot()

# %%
df.Close.plot(legend=True)
df.Close.rolling(20).mean().plot()
df.Close.rolling(60).mean().plot()

# %% [markdown]
# #### 20 日和 60 日的移動平均

# %%
df.Close.plot(legend=True)
df.Close.rolling(20).mean().plot(label="$MA_{20}$",legend=True)
df.Close.rolling(60).mean().plot(label="$MA_{60}$",legend=True)

# %% [markdown]
# #### 準備做預測
#
# 我們用個非常天真的模型...
#
# ![天真股票模型](images/naive.png)
#
# 網路上說這是線性的 (可能嗎)!

# %%
close = df.Close.values
len(close)
# Out:
# 300

# %%
x = close[:-1]
len(x)
# Out:
# 299

# %%
y = close[1:]
len(y)
# Out:
# 299

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %% [markdown]
# 哦, 真的有點像線性的, 我們之後用線性迴歸試試看。

# %% [markdown]
# ## 9 手工打造一個 DataFrame*
#
# 有時我們用手工打造一個簡單的 DataFrame, 可以更理解整個結構。其實很容易, 一個 DataFrame 基本上就包含兩個主要部份:
#
# * 資料本身: 通常一個二維陣列 (矩陣)
# * 行、列的名稱
#
# 我們來個簡單的小例子。

# %%
mydata = np.random.randn(4,3)  #4*3 矩陣

# %%
mydata
# Out:
# array([[-0.21310746, -1.1601671 ,  1.73921835],
#        [ 0.27681971, -0.13540213,  1.37533807],
#        [ 0.89119906,  1.69793315,  0.82425955],
#        [-0.30006223, -0.26934887, -0.36838848]])

# %% [markdown]
# 把行列的名字放進去, 就成一個 DataFrame。我們列的部份先讓 Python 自己產生。

# %%
df2 = pd.DataFrame(mydata, columns=list("ABC"))  #list 自動切出ABC
df2
# Out:
#           A         B         C
# 0 -0.213107 -1.160167  1.739218
# 1  0.276820 -0.135402  1.375338
# 2  0.891199  1.697933  0.824260
# 3 -0.300062 -0.269349 -0.368388

# %%
df3 = pd.DataFrame(np.random.randn(3,3), columns=list("ABC"))
df3
# Out:
#           A         B         C
# 0  0.523646 -0.996458  0.729805
# 1  0.307517  0.071134  0.141239
# 2  0.128727  0.744489  0.447138

# %% [markdown]
# #### 兩個表格上下貼起來
#
# 我們再來生一個 DataFrame, 再「貼」起來。

# %%
df3 = pd.DataFrame(np.random.randn(3,3), columns=list("ABC"))

# %%
df4 = pd.concat([df2,df3], axis=0)  #axis = 0, 上下接起來
df4
# Out:
#           A         B         C
# 0 -0.213107 -1.160167  1.739218
# 1  0.276820 -0.135402  1.375338
# 2  0.891199  1.697933  0.824260
# 3 -0.300062 -0.269349 -0.368388
# 0  0.523646 -0.996458  0.729805
# 1  0.307517  0.071134  0.141239
# 2  0.128727  0.744489  0.447138

# %%
df4.index = range(7)

# %%
df4
# Out:
#           A         B         C
# 0 -0.213107 -1.160167  1.739218
# 1  0.276820 -0.135402  1.375338
# 2  0.891199  1.697933  0.824260
# 3 -0.300062 -0.269349 -0.368388
# 4  0.523646 -0.996458  0.729805
# 5  0.307517  0.071134  0.141239
# 6  0.128727  0.744489  0.447138

# %% [markdown]
# 前面我們弄得亂七八糟的 index 重設一下。

# %%
df5 = pd.concat([df2,df3], axis=1)  #axis = 0, 左右接起來

# %%
df5
# Out:
#           A         B         C         A         B         C
# 0 -0.213107 -1.160167  1.739218  0.523646 -0.996458  0.729805
# 1  0.276820 -0.135402  1.375338  0.307517  0.071134  0.141239
# 2  0.891199  1.697933  0.824260  0.128727  0.744489  0.447138
# 3 -0.300062 -0.269349 -0.368388       NaN       NaN       NaN

# %% [markdown]
# #### 横向的貼

# %% [markdown]
# 等等, 這大小好像不太對也可以嗎? 答案是可以的!

# %% [markdown]
# #### 大一點的例子
#
# 我們來做前面「假的」學測資料。首先要有「假的」同學名單, 如果有興趣產生很多名字, 可以用這個服務。
#
# [中文姓名產生器](http://www.richyli.com/name/index.asp)

# %%
df_names = pd.read_csv('data/names.csv',names=['names'])
df_names
# Out:
#    names
# 0    羅雅慧
# 1    王紹尹
# 2    黃季坤
# 3    許正書
# 4    張鈞蓮
# ..   ...
# 95   陳君生
# 96   曾桂甫
# 97   林欣怡
# 98   林佳霖
# 99   胡筱芸
#
# [100 rows x 1 columns]

# %%
df_grades = pd.DataFrame(np.random.randint(6,16,(100,5)),
                        columns=['國文','英文','數學','社會','自然'])

# %%
df_grades.to_csv('data/grade_test.csv', index=0) #index 不存入
# Out:
#     國文  英文  數學  社會  自然
# 0    7  11  15   6  10
# 1   10  14   7  11   9
# 2   13  15  10   8   7
# 3   10  13  14  15  15
# 4   10   6   9   6  13
# ..  ..  ..  ..  ..  ..
# 95  12   8  13   9   6
# 96  12  13  14   8  12
# 97  15  11  10  12   8
# 98  12   6   9  15  10
# 99   7  11   6  13  13
#
# [100 rows x 5 columns]

# %%
df_score = pd.concat([df_names, df_grades], axis = 1)

# %%
df_score
# Out:
#    names  國文  英文  數學  社會  自然
# 0    羅雅慧   7  11  15   6  10
# 1    王紹尹  10  14   7  11   9
# 2    黃季坤  13  15  10   8   7
# 3    許正書  10  13  14  15  15
# 4    張鈞蓮  10   6   9   6  13
# ..   ...  ..  ..  ..  ..  ..
# 95   陳君生  12   8  13   9   6
# 96   曾桂甫  12  13  14   8  12
# 97   林欣怡  15  11  10  12   8
# 98   林佳霖  12   6   9  15  10
# 99   胡筱芸   7  11   6  13  13
#
# [100 rows x 6 columns]
